# %%
import pandas as pd
from pathlib import Path

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

# %% [markdown]
# ## Load the Data

# %%
# Load the parquet file
data_path = Path('./data/raw/c21_g19_sa2_health_conditions.parquet')
df = pd.read_parquet(data_path)

print(f"Dataset shape: {df.shape}")
print(f"Number of rows: {df.shape[0]:,}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Dataset shape: (1252020, 9)
# Number of rows: 1,252,020
# Number of columns: 9

# %% [markdown]
# ## Explore the Structure

# %%
# View column names and data types
print("Columns and Data Types:")
print(df.dtypes)
# Out:
# Columns and Data Types:
# DATAFLOW                                    object
# SEXP: Sex                                   object
# LTHP: Type of long-term health condition    object
# AGEP: Age                                   object
# REGION: Region                              object
# REGION_TYPE: Region Type                    object
# STATE: State                                object
# TIME_PERIOD: Time Period                     int64
# OBS_VALUE                                    int64
# dtype: object

# %%
df['LTHP: Type of long-term health condition'].value_counts()
# Out:
# LTHP: Type of long-term health condition
# _T: Total (Persons)                                              89430
# 71: Kidney disease                                               89430
# _N: Not stated                                                   89430
# 21: Asthma                                                       89430
# 111: Any other long-term health condition(s)                     89430
# 11: Arthritis                                                    89430
# 101: Stroke                                                      89430
# 121: No long-term health condition(s)                            89430
# 81: Lung condition (including COPD or emphysema)                 89430
# 41: Dementia (including Alzheimer's)                             89430
# 51: Diabetes (excluding gestational diabetes)                    89430
# 31: Cancer (including remission)                                 89430
# 61: Heart disease (including heart attack or angina)             89430
# 91: Mental health condition (including depression or anxiety)    89430
# Name: count, dtype: int64

# %%
df['AGEP: Age'].value_counts()
# Out:
# AGEP: Age
# 45_54: 45-54 years         125202
# 75_84: 75-84 years         125202
# _T: Total                  125202
# 65_74: 65-74 years         125202
# 15_24: 15-24 years         125202
# GE85: 85 years and over    125202
# 35_44: 35-44 years         125202
# 0_14: 0-14 years           125202
# 25_34: 25-34 years         125202
# 55_64: 55-64 years         125202
# Name: count, dtype: int64

# %%
df[(df['REGION: Region'] == '406021139: Coober Pedy') & (df['SEXP: Sex'] == '3: Persons') & (df['LTHP: Type of long-term health condition'] == '21: Asthma')]
# Out:
#                        DATAFLOW   SEXP: Sex  \
# 284577   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 546695   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 738251   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 741262   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 785916   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 848816   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 886406   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 965344   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 1070900  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 1120866  ABS:C21_G19_SA2(1.0.0)  3: Persons
#
#         LTHP: Type of long-term health condition                AGEP: Age  \
# 284577                                21: Asthma       35_44: 35-44 years
# 546695                                21: Asthma       15_24: 15-24 years
# 738251                                21: Asthma                _T: Total
# 741262                                21: Asthma       45_54: 45-54 years
# 785916                                21: Asthma  GE85: 85 years and over
# 848816                                21: Asthma       25_34: 25-34 years
# 886406                                21: Asthma       65_74: 65-74 years
# 965344                                21: Asthma       55_64: 55-64 years
# 1070900                               21: Asthma       75_84: 75-84 years
# 1120866                               21: Asthma         0_14: 0-14 years
#
#                  REGION: Region       REGION_TYPE: Region Type  \
# 284577   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 546695   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 738251   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 741262   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 785916   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 848816   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 886406   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 965344   406021139: Coober Pedy  SA2: Statistical Area Level 2
# 1070900  406021139: Coober Pedy  SA2: Statistical Area Level 2
# 1120866  406021139: Coober Pedy  SA2: Statistical Area Level 2
#
#                STATE: State  TIME_PERIOD: Time Period  OBS_VALUE
# 284577   4: South Australia                      2021         15
# 546695   4: South Australia                      2021          3
# 738251   4: South Australia                      2021        101
# 741262   4: South Australia                      2021         16
# 785916   4: South Australia                      2021          0
# 848816   4: South Australia                      2021         17
# 886406   4: South Australia                      2021         16
# 965344   4: South Australia                      2021         22
# 1070900  4: South Australia                      2021          8
# 1120866  4: South Australia                      2021          5

# %%
# Preview the first few rows
df.head(10)
# Out:
#                  DATAFLOW   SEXP: Sex  \
# 0  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 1  ABS:C21_G19_SA2(1.0.0)  2: Females
# 2  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 3  ABS:C21_G19_SA2(1.0.0)    1: Males
# 4  ABS:C21_G19_SA2(1.0.0)    1: Males
# 5  ABS:C21_G19_SA2(1.0.0)  2: Females
# 6  ABS:C21_G19_SA2(1.0.0)    1: Males
# 7  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 8  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 9  ABS:C21_G19_SA2(1.0.0)  3: Persons
#
#        LTHP: Type of long-term health condition                AGEP: Age  \
# 0                           _T: Total (Persons)       45_54: 45-54 years
# 1                            71: Kidney disease       75_84: 75-84 years
# 2                                _N: Not stated                _T: Total
# 3                                _N: Not stated       65_74: 65-74 years
# 4                                    21: Asthma       15_24: 15-24 years
# 5                            71: Kidney disease  GE85: 85 years and over
# 6  111: Any other long-term health condition(s)       35_44: 35-44 years
# 7                                 11: Arthritis       45_54: 45-54 years
# 8                                   101: Stroke       45_54: 45-54 years
# 9         121: No long-term health condition(s)  GE85: 85 years and over
#
#                                       REGION: Region  \
# 0                             406021139: Coober Pedy
# 1                      501021252: Gelorup - Stratham
# 2  503021043: Wembley - West Leederville - Glenda...
# 3              503021297: Perth (West) - Northbridge
# 4                                505021087: Herdsman
# 5                      505031255: Alkimos - Eglinton
# 6                              506011116: Roleystone
# 7           506021119: East Victoria Park - Carlisle
# 8                    507041175: Applecross - Ardross
# 9                              507051186: Cooloongup
#
#         REGION_TYPE: Region Type          STATE: State  \
# 0  SA2: Statistical Area Level 2    4: South Australia
# 1  SA2: Statistical Area Level 2  5: Western Australia
# 2  SA2: Statistical Area Level 2  5: Western Australia
# 3  SA2: Statistical Area Level 2  5: Western Australia
# 4  SA2: Statistical Area Level 2  5: Western Australia
# 5  SA2: Statistical Area Level 2  5: Western Australia
# 6  SA2: Statistical Area Level 2  5: Western Australia
# 7  SA2: Statistical Area Level 2  5: Western Australia
# 8  SA2: Statistical Area Level 2  5: Western Australia
# 9  SA2: Statistical Area Level 2  5: Western Australia
#
#    TIME_PERIOD: Time Period  OBS_VALUE
# 0                      2021        194
# 1                      2021          0
# 2                      2021       1080
# 3                      2021         41
# 4                      2021          0
# 5                      2021          0
# 6                      2021         31
# 7                      2021        137
# 8                      2021          5
# 9                      2021         29

# %%
# Basic statistics
df.describe()
# Out:
#        TIME_PERIOD: Time Period     OBS_VALUE
# count                 1252020.0  1.252020e+06
# mean                     2021.0  1.060002e+03
# std                         0.0  4.117564e+04
# min                      2021.0  0.000000e+00
# 25%                      2021.0  4.000000e+00
# 50%                      2021.0  3.300000e+01
# 75%                      2021.0  1.560000e+02
# max                      2021.0  2.542279e+07

# %% [markdown]
# ## Explore Unique Values in Key Columns

# %%
# Check unique values in each column
print("Unique values per column:")
for col in df.columns:
    n_unique = df[col].nunique()
    print(f"  {col}: {n_unique} unique values")
# Out:
# Unique values per column:
#   DATAFLOW: 1 unique values
#   SEXP: Sex: 3 unique values
#   LTHP: Type of long-term health condition: 14 unique values
#   AGEP: Age: 10 unique values
#   REGION: Region: 2981 unique values
#   REGION_TYPE: Region Type: 6 unique values
#   STATE: State: 10 unique values
#   TIME_PERIOD: Time Period: 1 unique values
#   OBS_VALUE: 20863 unique values

# %%
# Look at unique values in categorical columns (small number of unique values)
for col in df.columns:
    n_unique = df[col].nunique()
    if n_unique <= 30:  # Only show columns with few unique values
        print(f"\n{col} ({n_unique} values):")
        for val in sorted(df[col].unique(), key=str):
            print(f"  - {val}")
# Out:
# DATAFLOW (1 values):
#   - ABS:C21_G19_SA2(1.0.0)
#
# SEXP: Sex (3 values):
#   - 1: Males
#   - 2: Females
#   - 3: Persons
#
# LTHP: Type of long-term health condition (14 values):
#   - 101: Stroke
#   - 111: Any other long-term health condition(s)
#   - 11: Arthritis
#   - 121: No long-term health condition(s)
#   - 21: Asthma
#   - 31: Cancer (including remission)
#   - 41: Dementia (including Alzheimer's)
#   - 51: Diabetes (excluding gestational diabetes)
#   - 61: Heart disease (including heart attack or angina)
#   - 71: Kidney disease
#   - 81: Lung condition (including COPD or emphysema)
#   - 91: Mental health condition (including depression or anxiety)
#   - _N: Not stated
#   - _T: Total (Persons)
#
# AGEP: Age (10 values):
#   - 0_14: 0-14 years
#   - 15_24: 15-24 years
#   - 25_34: 25-34 years
#   - 35_44: 35-44 years
#   - 45_54: 45-54 years
#   - 55_64: 55-64 years
#   - 65_74: 65-74 years
#   - 75_84: 75-84 years
#   - GE85: 85 years and over
#   - _T: Total
#
# REGION_TYPE: Region Type (6 values):
#   - AUS: Australia
#   - GCCSA: Greater Capital City Statistical Areas
#   - SA2: Statistical Area Level 2
#   - SA3: Statistical Area Level 3
#   - SA4: Statistical Area Level 4
#   - STE: States and Territories
#
# STATE: State (10 values):
#   - 1: New South Wales
#   - 2: Victoria
#   - 3: Queensland
#   - 4: South Australia
#   - 5: Western Australia
#   - 6: Tasmania
#   - 7: Northern Territory
#   - 8: Australian Capital Territory
#   - 9: Other Territories
#   - AUS: Australia
#
# TIME_PERIOD: Time Period (1 values):
#   - 2021

# %% [markdown]
# ## Health Conditions Analysis

# %%
# Find health condition column (likely contains 'LTHP' or 'health')
health_cols = [c for c in df.columns if 'LTHP' in c.upper() or 'health' in c.lower() or 'condition' in c.lower()]
print(f"Potential health condition columns: {health_cols}")

# If found, show unique health conditions
if health_cols:
    health_col = health_cols[0]
    print(f"\nHealth conditions in '{health_col}':")
    for val in df[health_col].unique():
        print(f"  - {val}")
# Out:
# Potential health condition columns: ['LTHP: Type of long-term health condition']
#
# Health conditions in 'LTHP: Type of long-term health condition':
#   - _T: Total (Persons)
#   - 71: Kidney disease
#   - _N: Not stated
#   - 21: Asthma
#   - 111: Any other long-term health condition(s)
#   - 11: Arthritis
#   - 101: Stroke
#   - 121: No long-term health condition(s)
#   - 81: Lung condition (including COPD or emphysema)
#   - 41: Dementia (including Alzheimer's)
#   - 51: Diabetes (excluding gestational diabetes)
#   - 31: Cancer (including remission)
#   - 61: Heart disease (including heart attack or angina)
#   - 91: Mental health condition (including depression or anxiety)

# %% [markdown]
# ## Geographic Distribution

# %%
# Find region/geography columns
geo_cols = [c for c in df.columns if any(term in c.upper() for term in ['REGION', 'SA2', 'STATE', 'ASGS', 'GEO'])]
print(f"Geographic columns: {geo_cols}")

# Show number of unique regions
for col in geo_cols:
    print(f"\n{col}: {df[col].nunique()} unique values")
    if df[col].nunique() <= 20:
        print(f"Values: {df[col].unique().tolist()}")
# Out:
# Geographic columns: ['REGION: Region', 'REGION_TYPE: Region Type', 'STATE: State']
#
# REGION: Region: 2981 unique values
#
# REGION_TYPE: Region Type: 6 unique values
# Values: ['SA2: Statistical Area Level 2', 'SA3: Statistical Area Level 3', 'GCCSA: Greater Capital City Statistical Areas', 'SA4: Statistical Area Level 4', 'STE: States and Territories', 'AUS: Australia']
#
# STATE: State: 10 unique values
# Values: ['4: South Australia', '5: Western Australia', '6: Tasmania', '2: Victoria', '3: Queensland', '1: New South Wales', '7: Northern Territory', '8: Australian Capital Territory', '9: Other Territories', 'AUS: Australia']

# %% [markdown]
# ## Sample Data by Region

# %%
# Show a sample of data for one region (first unique region value)
if geo_cols:
    region_col = geo_cols[0]
    sample_region = df[region_col].iloc[0]
    print(f"Sample data for region: {sample_region}")
    display(df[df[region_col] == sample_region].head(20))
# Out:
# Sample data for region: 406021139: Coober Pedy
#                      DATAFLOW   SEXP: Sex  \
# 0      ABS:C21_G19_SA2(1.0.0)  3: Persons
# 237    ABS:C21_G19_SA2(1.0.0)  2: Females
# 754    ABS:C21_G19_SA2(1.0.0)  3: Persons
# 872    ABS:C21_G19_SA2(1.0.0)    1: Males
# 951    ABS:C21_G19_SA2(1.0.0)  3: Persons
# 4431   ABS:C21_G19_SA2(1.0.0)  3: Persons
# 23191  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 24238  ABS:C21_G19_SA2(1.0.0)  2: Females
# 29069  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 31248  ABS:C21_G19_SA2(1.0.0)  3: Persons
# 31973  ABS:C21_G19_SA2(1.0.0)    1: Males
# 48333  ABS:C21_G19_SA2(1.0.0)  2: Females
# 58132  ABS:C21_G19_SA2(1.0.0)    1: Males
# 61915  ABS:C21_G19_SA2(1.0.0)    1: Males
# 64556  ABS:C21_G19_SA2(1.0.0)  2: Females
# 64664  ABS:C21_G19_SA2(1.0.0)  2: Females
# 64765  ABS:C21_G19_SA2(1.0.0)    1: Males
# 69779  ABS:C21_G19_SA2(1.0.0)    1: Males
# 73933  ABS:C21_G19_SA2(1.0.0)    1: Males
# 74431  ABS:C21_G19_SA2(1.0.0)  3: Persons
#
#                 LTHP: Type of long-term health condition  \
# 0                                    _T: Total (Persons)
# 237                 41: Dementia (including Alzheimer's)
# 754        51: Diabetes (excluding gestational diabetes)
# 872                                  _T: Total (Persons)
# 951         111: Any other long-term health condition(s)
# 4431                                 _T: Total (Persons)
# 23191                                        101: Stroke
# 24238              121: No long-term health condition(s)
# 29069               41: Dementia (including Alzheimer's)
# 31248                                _T: Total (Persons)
# 31973      51: Diabetes (excluding gestational diabetes)
# 48333                                      11: Arthritis
# 58132                                 71: Kidney disease
# 61915  91: Mental health condition (including depress...
# 64556              121: No long-term health condition(s)
# 64664                                        101: Stroke
# 64765                                 71: Kidney disease
# 69779                                      11: Arthritis
# 73933                   31: Cancer (including remission)
# 74431                   31: Cancer (including remission)
#
#                      AGEP: Age          REGION: Region  \
# 0           45_54: 45-54 years  406021139: Coober Pedy
# 237         35_44: 35-44 years  406021139: Coober Pedy
# 754         75_84: 75-84 years  406021139: Coober Pedy
# 872         25_34: 25-34 years  406021139: Coober Pedy
# 951         45_54: 45-54 years  406021139: Coober Pedy
# 4431          0_14: 0-14 years  406021139: Coober Pedy
# 23191       45_54: 45-54 years  406021139: Coober Pedy
# 24238         0_14: 0-14 years  406021139: Coober Pedy
# 29069       75_84: 75-84 years  406021139: Coober Pedy
# 31248       65_74: 65-74 years  406021139: Coober Pedy
# 31973       15_24: 15-24 years  406021139: Coober Pedy
# 48333       25_34: 25-34 years  406021139: Coober Pedy
# 58132  GE85: 85 years and over  406021139: Coober Pedy
# 61915       15_24: 15-24 years  406021139: Coober Pedy
# 64556       35_44: 35-44 years  406021139: Coober Pedy
# 64664       65_74: 65-74 years  406021139: Coober Pedy
# 64765       45_54: 45-54 years  406021139: Coober Pedy
# 69779       35_44: 35-44 years  406021139: Coober Pedy
# 73933       55_64: 55-64 years  406021139: Coober Pedy
# 74431  GE85: 85 years and over  406021139: Coober Pedy
#
#             REGION_TYPE: Region Type        STATE: State  \
# 0      SA2: Statistical Area Level 2  4: South Australia
# 237    SA2: Statistical Area Level 2  4: South Australia
# 754    SA2: Statistical Area Level 2  4: South Australia
# 872    SA2: Statistical Area Level 2  4: South Australia
# 951    SA2: Statistical Area Level 2  4: South Australia
# 4431   SA2: Statistical Area Level 2  4: South Australia
# 23191  SA2: Statistical Area Level 2  4: South Australia
# 24238  SA2: Statistical Area Level 2  4: South Australia
# 29069  SA2: Statistical Area Level 2  4: South Australia
# 31248  SA2: Statistical Area Level 2  4: South Australia
# 31973  SA2: Statistical Area Level 2  4: South Australia
# 48333  SA2: Statistical Area Level 2  4: South Australia
# 58132  SA2: Statistical Area Level 2  4: South Australia
# 61915  SA2: Statistical Area Level 2  4: South Australia
# 64556  SA2: Statistical Area Level 2  4: South Australia
# 64664  SA2: Statistical Area Level 2  4: South Australia
# 64765  SA2: Statistical Area Level 2  4: South Australia
# 69779  SA2: Statistical Area Level 2  4: South Australia
# 73933  SA2: Statistical Area Level 2  4: South Australia
# 74431  SA2: Statistical Area Level 2  4: South Australia
#
#        TIME_PERIOD: Time Period  OBS_VALUE
# 0                          2021        194
# 237                        2021          0
# 754                        2021         20
# 872                        2021         99
# 951                        2021         16
# 4431                       2021        188
# 23191                      2021          0
# 24238                      2021         58
# 29069                      2021          4
# 31248                      2021        246
# 31973                      2021          0
# 48333                      2021          0
# 58132                      2021          0
# 61915                      2021          0
# 64556                      2021         37
# 64664                      2021          0
# 64765                      2021          0
# 69779                      2021          5
# 73933                      2021          4
# 74431                      2021          4

# %% [markdown]
# ## Value Distribution

# %%
# Find the observation/value column
value_cols = [c for c in df.columns if any(term in c.upper() for term in ['OBS', 'VALUE', 'COUNT'])]
print(f"Value columns: {value_cols}")

if value_cols:
    value_col = value_cols[0]
    print(f"\nStatistics for '{value_col}':")
    print(df[value_col].describe())
    
    print(f"\nNull values: {df[value_col].isna().sum()}")
    print(f"Zero values: {(df[value_col] == 0).sum()}")
# Out:
# Value columns: ['OBS_VALUE']
#
# Statistics for 'OBS_VALUE':
# count    1.252020e+06
# mean     1.060002e+03
# std      4.117564e+04
# min      0.000000e+00
# 25%      4.000000e+00
# 50%      3.300000e+01
# 75%      1.560000e+02
# max      2.542279e+07
# Name: OBS_VALUE, dtype: float64
#
# Null values: 0
# Zero values: 247548

# %% [markdown]
# ## Memory Usage

# %%
# Check memory usage
print("Memory usage by column:")
print(df.memory_usage(deep=True))
print(f"\nTotal memory: {df.memory_usage(deep=True).sum() / 1024 / 1024:.2f} MB")
# Out:
# Memory usage by column:
# Index                                             132
# DATAFLOW                                     88893420
# SEXP: Sex                                    73034500
# LTHP: Type of long-term health condition    100698180
# AGEP: Age                                    83134128
# REGION: Region                               93823800
# REGION_TYPE: Region Type                     97872180
# STATE: State                                 81556020
# TIME_PERIOD: Time Period                     10016160
# OBS_VALUE                                    10016160
# dtype: int64
#
# Total memory: 609.44 MB

# %%
# What are the top 5 SA2 regions per state for Diabetes (excluding gestational diabetes)?
diabetes_df = df[
    (df['Health Condition'] == 'Diabetes') & 
    (df['Type of Diabetes'] != 'Gestational Diabetes')
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Projects\ABS_Data\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Health Condition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 # What are the top 5 SA2 regions per state for Diabetes (excluding gestational diabetes)?
#       2 diabetes_df = df[
# ----> 3     (df['Health Condition'] == 'Diabetes') &
#       4     (df['Type of Diabetes'] != 'Gestational Diabetes')
#       5 ]
#
# File ~\Projects\ABS_Data\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\Projects\ABS_Data\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Health Condition'
